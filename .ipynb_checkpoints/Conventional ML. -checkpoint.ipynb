# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from sklearn.svm import SVC
import seaborn as sns
import numpy as np

# %% [markdown]
# ## EDA

# %%
train = pd.read_csv('input/train.csv')
test = pd.read_csv('input/test.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### 'age' and 'cabin' have lots of NA values. Is it due to death?

# %%
plt.subplot(1,2,2)
train.loc[train.Cabin.notna(), 'Survived'].hist()
plt.title('with cabin')
plt.subplot(1,2,1)
train.loc[train.Cabin.isna(), 'Survived'].hist()
plt.title('w/o cabin')
plt.show()

# %%
plt.subplot(1,2,2)
train.loc[train.Age.notna(), 'Survived'].hist()
plt.title('with Age')
plt.subplot(1,2,1)
train.loc[train.Age.isna(), 'Survived'].hist()
plt.title('w/o Age')
plt.show()

# %% [markdown]
# Passengers with 'Cabin' information is likely to survive

# %% [markdown]
# ### survive rate wrt Age

# %%
plt.subplots(2,2,figsize=(20,10))
plt.subplot(141)
sns.violinplot(x='Pclass', y='Age', hue='Survived',split=True,data=train)
plt.subplot(142)
sns.violinplot(x='Sex', y='Age', hue='Survived',split=True,data=train)
plt.subplot(143)
sns.violinplot(x='Survived', y='Age', data=train)
plt.subplot(144)
sns.catplot(x='Survived', hue='Sex', col='Pclass', data=train, kind='count')

# %%
fig, ax= plt.subplots(2,2,figsize=(20,20))
feature_list = ['Sex', 'Pclass', 'SibSp', 'Parch']
for index,feature in enumerate(feature_list):
    sns.countplot(x='Survived', hue=feature, data=train, ax=fig.axes[index])
plt.show()

# %% [markdown]
# #### Observations:
# * Age <10 and age >50 are more likely to survive.
# * Children are more likely to survive.
# * 'SibSp' or 'Parch'=0 is more likely to survive

# %%
train['Initial'] = train.Name.str.extract(r'(\w+\.)')

# %%
a = train.groupby('Initial').aggregate({'Age':['mean'], 'Initial':'count'})
b = pd.crosstab(train.Initial, train.Sex)

# %%
a.columns=a.columns.map('_'.join)

# %%
pd.concat([a,b], axis=1)
# Out:
#             Age_mean  Initial_count  female  male
# Initial
# Capt.      70.000000              1       0     1
# Col.       58.000000              2       0     2
# Countess.  33.000000              1       1     0
# Don.       40.000000              1       0     1
# Dr.        42.000000              7       1     6
# Jonkheer.  38.000000              1       0     1
# Lady.      48.000000              1       1     0
# Major.     48.500000              2       0     2
# Master.     4.574167             40       0    40
# Miss.      21.773973            182     182     0
# Mlle.      24.000000              2       2     0
# Mme.       24.000000              1       1     0
# Mr.        32.368090            517       0   517
# Mrs.       35.898148            125     125     0
# Ms.        28.000000              1       1     0
# Rev.       43.166667              6       0     6
# Sir.       49.000000              1       0     1

# %% [markdown]
# * there are rare titles. to be cleaned

# %%
sns.catplot(data=train.loc[(train.Age<17)&(train.Sex=='female')], x='Initial', hue='Survived', col='Pclass', kind='count')

# %%
sns.catplot(data=train.loc[(train.Age<17)&(train.Sex=='male')], x='Initial', hue='Survived', col='Pclass', kind='count')

# %% [markdown]
# * Even for children, 'Pclass' decides the survival rate.

# %% [markdown]
# ### Fare

# %%
plt.subplots(figsize=(20,10))
sns.boxplot(x='Survived', y='Fare', data=train)
sns.catplot(data=train, y='Fare', x='Survived', hue='Sex', kind='box', col='Pclass',height=10, aspect=0.5)

# %%
train['fare_range'] = pd.qcut(train.Fare, 3)
train['fare_range'].map(dict(zip(train['fare_range'].cat.categories,['poor', 'mid', 'rich'])))
# Out:
# 0      poor
# 1      rich
# 2      poor
# 3      rich
# 4      poor
#        ...
# 886     mid
# 887    rich
# 888     mid
# 889    rich
# 890    poor
# Name: fare_range, Length: 891, dtype: category
# Categories (3, object): [poor < mid < rich]

# %%
sns.catplot(x='fare_range', y='Survived', kind='point', data=train)

# %% [markdown]
# ### apply transformations

# %%
train['cabin_cat'] = train.Cabin.str[0]
train.cabin_cat.fillna('no_cabin', inplace=True)
train.cabin_cat.mask(train.cabin_cat!='no_cabin', 'has_cabin')

#'Age' can be inferred by the title in names
train['Initial'] = train.Name.str.extract(r'(\w+\.)')
train['Age'] = train.groupby('Initial')['Age'].transform(lambda x: x.fillna(x.mean()))
